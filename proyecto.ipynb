# %% [markdown]
# # Regresión lineal: predecir los gastos médicos de pacientes
# ---

# %% [markdown]
# Se utiliza esta base de datos: [insurance.csv](https://www.kaggle.com/mirichoi0218/insurance) de Kaggle en el cual se presentan datos de seguros médicos.

# %% [markdown]
# ## Descarga e instalación de librerías

# %% [markdown]
# Lo primero que se hará es descargar la librería **[regressors](https://pypi.org/project/regressors/)** que ayudará a hacer un análisis más profundo sobre la regresión lineal.

# %%
# %pip install --upgrade pip setuptools==57.5.0
# %pip install regressors
# Out:
# Requirement already satisfied: pip in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (23.0.1)
# Requirement already satisfied: setuptools==57.5.0 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (57.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: regressors in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (0.0.3)
# Requirement already satisfied: pandas in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from regressors) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.17 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from regressors) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from regressors) (1.10.1)
# Requirement already satisfied: numpy>=1.6.1 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from regressors) (1.24.2)
# Requirement already satisfied: statsmodels>=0.6.1 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from regressors) (0.13.5)
# Requirement already satisfied: seaborn in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from regressors) (0.12.2)
# Requirement already satisfied: matplotlib in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from regressors) (3.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from scikit-learn>=0.17->regressors) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from scikit-learn>=0.17->regressors) (1.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from statsmodels>=0.6.1->regressors) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from statsmodels>=0.6.1->regressors) (23.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from pandas->regressors) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from pandas->regressors) (2023.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from matplotlib->regressors) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from matplotlib->regressors) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from matplotlib->regressors) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from matplotlib->regressors) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from matplotlib->regressors) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from matplotlib->regressors) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from matplotlib->regressors) (4.39.3)
# Requirement already satisfied: zipp>=3.1.0 in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->regressors) (3.15.0)
# Requirement already satisfied: six in /home/user/anaconda3/envs/entorno/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels>=0.6.1->regressors) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
sns.set(style='whitegrid', context='notebook')

# %% [markdown]
# ## Descargando los datos
# Leyendo los datos csv con pandas

# %% [markdown]
# # La variable predictora sera charges

# %%
df=pd.read_csv('./data/insurance.csv')
df.head() # mostrandos los primeros 5 registros
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## Analizando los datos
# Se observará cómo se distribuyen los datos de la variable a predecir.

# %%
print(df.shape)
df.charges.hist(bins = 40)
# Out:
# (1338, 7)
# <Axes: >

# %% [markdown]
# Algo que analizar, según este gráfico, es entender qué está pasando con los datos arriba de los 50,000.

# %%
df[df.charges>50000]
df=df[df.charges<50000] # Se analizaran solo los datos donde charges es menor a 50000

# %% [markdown]
# En este caso, al ser pocos datos (6 de 1338), eliminaremos estos datos atípicos. A modo didáctico producen más ruido en la predicción que se está intentando hacer en este ejercicio.
#
# Sin embargo es importante aclarar que **NO SE DEBEN ELIMINAR** datos atípicos sin antes conocer a alguien que conozca o sea experto en los datos para que pueda guiarnos mejor sobre ellos.

# %% [markdown]
# ## Viendo correlaciones
# Ahora entendamos nuestros datos, viendo cómo se distribuyen y correlacionan.

# %%
import matplotlib.pyplot as plt
sns.pairplot(df, height=2.5)
plt.show()

# %% [markdown]
# Puntos interesantes a ver:
#
# - Hay 3 grupos de personas diferentes que se clasifican en edad / cargos, esto puede ser un punto a analizar después.
#
# En general los valores se distribuyen de manera esperada. Con valores extremos en el caso de los cargos, sin embargo esto es de esperarse pues los cargos en los hospitales pueden variar mucho por quedarse un día más en el hospital o incluso por procedimientos extras.
#
# - Parece que los datos están limpios, la variable de índice de masa corporal se distribuye de manera normal o gausiana, lo cual sería esperado en un índice de este tipo.

# %%
import numpy as np
numeric_cols = ['age', 'bmi', 'children', 'charges']
cm = np.corrcoef(df[numeric_cols].values.T)
sns.set(font_scale=1.5)
sns.heatmap(cm, annot=True, yticklabels=numeric_cols,xticklabels=numeric_cols)
# Out:
# <Axes: >

# %% [markdown]
# ## Utilizando las demás variables
# Las demás variables son variables categoricas, sexo, fumador, región. Para poder utilizarlas utilizaremos la función get_dummies de pandas.
#
# Ahora la verás en acción

# %%
df=pd.get_dummies(df, columns=['sex', 'smoker', 'region'], drop_first=True)
df.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400         0           1                 0
# 1   18  33.770         1   1725.55230         1           0                 0
# 2   28  33.000         3   4449.46200         1           0                 0
# 3   33  22.705         0  21984.47061         1           0                 1
# 4   32  28.880         0   3866.85520         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %% [markdown]
# ## Creando modelos
# Primero se usará un modelo con todas las variables.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_cols = list(set(df.columns)-set(['charges']))
y_col = ['charges']

X = df[X_cols].values
y = df[y_col].values

X_train, X_test, y_train, y_test = train_test_split(X,y)
sc_X = StandardScaler().fit(X)
sc_y = StandardScaler().fit(y)

X_train = sc_X.transform(X_train)
X_test = sc_X.transform(X_test)
y_train = sc_y.transform(y_train)
y_test = sc_y.transform(y_test)

model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
y_pred.shape
# Out:
# (333, 1)

# %% [markdown]
# ## Funciones de métricas
# El siguiente punto es calcular las métricas del modelo.

# %% [markdown]
# El siguiente código muestra un resumen general de los resultados.

# %% [markdown]
# Finalmente tenemos la función que calcula los residuales. Es importante notar que es una simple resta entre los valores reales y los predichos.

# %% [markdown]
# ## Segundo modelo
# Estos resultados de arriba son buenos, pero se pueden mejorar. Intentaremos hacer algunas transformaciones sobre las variables que pueden ser de utilidad.

# %% [markdown]
# Analizando el segundo modelo
